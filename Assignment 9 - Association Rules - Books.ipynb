# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from mlxtend.frequent_patterns import apriori,association_rules
from mlxtend.preprocessing import TransactionEncoder

# %%
book_data = pd.read_csv('book.csv')
book_data.sample(5)
# Out:
#       ChildBks  YouthBks  CookBks  DoItYBks  RefBks  ArtBks  GeogBks  \
# 1700         0         0        0         0       0       0        0
# 1608         0         0        1         0       0       0        1
# 1319         0         0        0         0       0       0        0
# 134          0         0        1         0       0       0        0
# 1818         0         0        0         0       0       0        0
#
#       ItalCook  ItalAtlas  ItalArt  Florence
# 1700         0          0        0         0
# 1608         0          0        0         0
# 1319         0          0        0         0
# 134          0          0        0         0
# 1818         0          0        0         0

# %%
book_data.shape
# Out:
# (2000, 11)

# %%
book_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2000 entries, 0 to 1999
# Data columns (total 11 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   ChildBks   2000 non-null   int64
#  1   YouthBks   2000 non-null   int64
#  2   CookBks    2000 non-null   int64
#  3   DoItYBks   2000 non-null   int64
#  4   RefBks     2000 non-null   int64
#  5   ArtBks     2000 non-null   int64
#  6   GeogBks    2000 non-null   int64
#  7   ItalCook   2000 non-null   int64
#  8   ItalAtlas  2000 non-null   int64
#  9   ItalArt    2000 non-null   int64
#  10  Florence   2000 non-null   int64
# dtypes: int64(11)
# memory usage: 172.0 KB

# %% [markdown]
# ### Apriori Algorithm for min_support = 0.1

# %%
frequent_itemsets1 = apriori(book_data, min_support=0.1, use_colnames=True)
frequent_itemsets1
# Out:
#     support                       itemsets
# 0    0.4230                     (ChildBks)
# 1    0.2475                     (YouthBks)
# 2    0.4310                      (CookBks)
# 3    0.2820                     (DoItYBks)
# 4    0.2145                       (RefBks)
# 5    0.2410                       (ArtBks)
# 6    0.2760                      (GeogBks)
# 7    0.1135                     (ItalCook)
# 8    0.1085                     (Florence)
# 9    0.1650           (ChildBks, YouthBks)
# 10   0.2560            (ChildBks, CookBks)
# 11   0.1840           (DoItYBks, ChildBks)
# 12   0.1515             (ChildBks, RefBks)
# 13   0.1625             (ChildBks, ArtBks)
# 14   0.1950            (ChildBks, GeogBks)
# 15   0.1620            (CookBks, YouthBks)
# 16   0.1155           (DoItYBks, YouthBks)
# 17   0.1010             (ArtBks, YouthBks)
# 18   0.1205            (YouthBks, GeogBks)
# 19   0.1875            (DoItYBks, CookBks)
# 20   0.1525              (CookBks, RefBks)
# ...

# %% [markdown]
# ### Rules when min_support = 0.1 and min_threshold for lift is 0.5

# %%
rules1 = association_rules(frequent_itemsets1, metric="lift", min_threshold=0.5)
rules1
# Out:
#            antecedents         consequents  antecedent support  \
# 0           (ChildBks)          (YouthBks)              0.4230
# 1           (YouthBks)          (ChildBks)              0.2475
# 2           (ChildBks)           (CookBks)              0.4230
# 3            (CookBks)          (ChildBks)              0.4310
# 4           (DoItYBks)          (ChildBks)              0.2820
# ..                 ...                 ...                 ...
# 95  (CookBks, GeogBks)            (ArtBks)              0.1925
# 96   (ArtBks, GeogBks)           (CookBks)              0.1275
# 97           (CookBks)   (ArtBks, GeogBks)              0.4310
# 98            (ArtBks)  (CookBks, GeogBks)              0.2410
# 99           (GeogBks)   (CookBks, ArtBks)              0.2760
#
#     consequent support  support  confidence      lift  leverage  conviction
# 0               0.2475   0.1650    0.390071  1.576044  0.060308    1.233750
# ...

# %%
rules1.sort_values('lift',ascending = False)
# Out:
#            antecedents          consequents  antecedent support  \
# 28           (CookBks)           (ItalCook)              0.4310
# 29          (ItalCook)            (CookBks)              0.1135
# 76  (ChildBks, ArtBks)            (GeogBks)              0.1625
# 81           (GeogBks)   (ChildBks, ArtBks)              0.2760
# 87            (ArtBks)  (DoItYBks, CookBks)              0.2410
# ..                 ...                  ...                 ...
# 4           (DoItYBks)           (ChildBks)              0.2820
# 12           (CookBks)           (YouthBks)              0.4310
# 13          (YouthBks)            (CookBks)              0.2475
# 3            (CookBks)           (ChildBks)              0.4310
# 2           (ChildBks)            (CookBks)              0.4230
#
#     consequent support  support  confidence      lift  leverage  conviction
# 28              0.1135   0.1135    0.263341  2.320186  0.064582    1.203406
# ...

# %%
plt.scatter(rules1['support'], rules1['confidence'])
plt.xlabel('support')
plt.ylabel('confidence')
plt.title('Support vs Confidence')
plt.show()

# %% [markdown]
# ### Rules when min_support = 0.1 and min_threshold for confidence is 0.5

# %%
rules2 = association_rules(frequent_itemsets1, metric="confidence", min_threshold=0.5)
rules2
# Out:
#              antecedents          consequents  antecedent support  \
# 0             (YouthBks)           (ChildBks)              0.2475
# 1             (ChildBks)            (CookBks)              0.4230
# 2              (CookBks)           (ChildBks)              0.4310
# 3             (DoItYBks)           (ChildBks)              0.2820
# 4               (RefBks)           (ChildBks)              0.2145
# 5               (ArtBks)           (ChildBks)              0.2410
# 6              (GeogBks)           (ChildBks)              0.2760
# 7             (YouthBks)            (CookBks)              0.2475
# 8             (DoItYBks)            (CookBks)              0.2820
# 9               (RefBks)            (CookBks)              0.2145
# 10              (ArtBks)            (CookBks)              0.2410
# 11             (GeogBks)            (CookBks)              0.2760
# 12            (ItalCook)            (CookBks)              0.1135
# ...

# %%
rules2 = rules2.sort_values(['confidence', 'lift'], ascending =[False, False])
rules2
# Out:
#              antecedents          consequents  antecedent support  \
# 12            (ItalCook)            (CookBks)              0.1135
# 41    (DoItYBks, ArtBks)            (CookBks)              0.1235
# 44   (DoItYBks, GeogBks)            (CookBks)              0.1325
# 48     (ArtBks, GeogBks)            (CookBks)              0.1275
# 24    (ChildBks, RefBks)            (CookBks)              0.1515
# 25     (CookBks, RefBks)           (ChildBks)              0.1525
# 39     (ArtBks, GeogBks)           (ChildBks)              0.1275
# 17   (CookBks, YouthBks)           (ChildBks)              0.1620
# 20  (DoItYBks, ChildBks)            (CookBks)              0.1840
# 35   (DoItYBks, GeogBks)           (ChildBks)              0.1325
# 18  (ChildBks, YouthBks)            (CookBks)              0.1650
# 21   (DoItYBks, CookBks)           (ChildBks)              0.1875
# 27    (ChildBks, ArtBks)            (CookBks)              0.1625
# ...

# %%
plt.scatter(rules2['support'], rules2['confidence'])
plt.xlabel('support')
plt.ylabel('confidence')
plt.title('Support vs Confidence')
plt.show()

# %% [markdown]
# ### Rules when min_support = 0.1 and min_threshold for lift is 1.2

# %%
rule5 = association_rules(frequent_itemsets1,metric='lift',min_threshold=1.2)
rule5
# Out:
#            antecedents         consequents  antecedent support  \
# 0           (ChildBks)          (YouthBks)              0.4230
# 1           (YouthBks)          (ChildBks)              0.2475
# 2           (ChildBks)           (CookBks)              0.4230
# 3            (CookBks)          (ChildBks)              0.4310
# 4           (DoItYBks)          (ChildBks)              0.2820
# ..                 ...                 ...                 ...
# 95  (CookBks, GeogBks)            (ArtBks)              0.1925
# 96   (ArtBks, GeogBks)           (CookBks)              0.1275
# 97           (CookBks)   (ArtBks, GeogBks)              0.4310
# 98            (ArtBks)  (CookBks, GeogBks)              0.2410
# 99           (GeogBks)   (CookBks, ArtBks)              0.2760
#
#     consequent support  support  confidence      lift  leverage  conviction
# 0               0.2475   0.1650    0.390071  1.576044  0.060308    1.233750
# ...

# %%
plt.scatter(rule5['support'], rule5['confidence'])
plt.xlabel('support')
plt.ylabel('confidence')
plt.title('Support vs Confidence')
plt.show()

# %% [markdown]
# ### Apriori Algorithm for min_support = 0.2

# %%
frequent_itemsets2 = apriori(book_data, min_support=0.2, use_colnames=True)
frequent_itemsets2
# Out:
#    support             itemsets
# 0   0.4230           (ChildBks)
# 1   0.2475           (YouthBks)
# 2   0.4310            (CookBks)
# 3   0.2820           (DoItYBks)
# 4   0.2145             (RefBks)
# 5   0.2410             (ArtBks)
# 6   0.2760            (GeogBks)
# 7   0.2560  (ChildBks, CookBks)

# %% [markdown]
# ### Rules when min_support = 0.2 and min_threshold for lift is 0.5

# %%
rules3 = association_rules(frequent_itemsets2, metric="lift", min_threshold=0.1)
rules3
# Out:
#   antecedents consequents  antecedent support  consequent support  support  \
# 0  (ChildBks)   (CookBks)               0.423               0.431    0.256
# 1   (CookBks)  (ChildBks)               0.431               0.423    0.256
#
#    confidence      lift  leverage  conviction
# 0    0.605201  1.404179  0.073687    1.441240
# 1    0.593968  1.404179  0.073687    1.421069

# %%
plt.scatter(rules3['support'], rules3['confidence'])
plt.xlabel('support')
plt.ylabel('confidence')
plt.title('Support vs Confidence')
plt.show()

# %% [markdown]
# ### Rules when min_support = 0.2 and min_threshold for confidence is 0.5

# %%
rules4 = association_rules(frequent_itemsets2, metric="confidence", min_threshold=0.5)
rules4
# Out:
#   antecedents consequents  antecedent support  consequent support  support  \
# 0  (ChildBks)   (CookBks)               0.423               0.431    0.256
# 1   (CookBks)  (ChildBks)               0.431               0.423    0.256
#
#    confidence      lift  leverage  conviction
# 0    0.605201  1.404179  0.073687    1.441240
# 1    0.593968  1.404179  0.073687    1.421069

# %%
plt.scatter(rules4['support'], rules4['confidence'])
plt.xlabel('support')
plt.ylabel('confidence')
plt.title('Support vs Confidence')
plt.show()

# %% [markdown]
# ### Rules when min_support = 0.2 and min_threshold for lift is 1.2

# %%
rules6 = association_rules(frequent_itemsets2, metric="lift", min_threshold=1.2)
rules6
# Out:
#   antecedents consequents  antecedent support  consequent support  support  \
# 0  (ChildBks)   (CookBks)               0.423               0.431    0.256
# 1   (CookBks)  (ChildBks)               0.431               0.423    0.256
#
#    confidence      lift  leverage  conviction
# 0    0.605201  1.404179  0.073687    1.441240
# 1    0.593968  1.404179  0.073687    1.421069

# %%
plt.scatter(rules6['support'], rules6['confidence'])
plt.xlabel('support')
plt.ylabel('confidence')
plt.title('Support vs Confidence')
plt.show()
